// %%
int counter = 10;
Console.WriteLine("cell1: hello from ClrKernel");

// %%
class Accumulator { public int Total { get; private set; } public void Add(int v) => Total += v; }
var acc = new Accumulator();
acc.Add(counter); acc.Add(32);
Console.WriteLine($"cell2: total = {acc.Total}");

// %%
// THE async test: output after await must be preserved
var sw = System.Diagnostics.Stopwatch.StartNew();
await Task.Delay(1500);
Console.WriteLine($"cell3: after await {sw.ElapsedMilliseconds}ms, counter={counter}");

// %%
Console.WriteLine("cell4: void cell (the nbclient crash regression test)");

// %%
counter + acc.Total
